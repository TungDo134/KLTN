# %%
import sys
sys.path.append("D:/KLTN/Project/BE_ChatBot")

from dotenv import load_dotenv
load_dotenv()

from src.pipeline.rag_pipline import RAGStorage
RAGStorage().build_vector_db()
# Out:
# 📁 Cache dir embedding model: D:\KLTN\Project\BE_ChatBot\src\model\embeddings
#
#
# - Chạy embedding model bằng: 'cuda'
#
# 🔧 Provider : huggingface
# 🔧 Model    : AITeamVN/Vietnamese_Embedding
# 🔧 Device   : cuda
# 🔧 Cache    : D:\KLTN\Project\BE_ChatBot\src\model\embeddings
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# 📂 Tìm thấy 6 file JSON: ['dalat_merged.json', 'danang_merged.json', 'hanoi_merged.json', 'hcm_merged.json', 'nhatrang_merged.json', 'vungtau_merged.json']
# ✅ Load xong: 11308 địa điểm từ 6 file
# ============================================================
# Splitting documents into chunks...
# Split into 11308 chunks
#
# [Chunk 1] DL_0001 | 364 chars
# Khu du lịch Thác Datanla là một địa điểm thuộc Đà Lạt. Loại hình: waterfall. Các hoạt động nổi bật: ...
#
# [Chunk 2] DL_0002 | 322 chars
# Đường Hầm Điêu Khắc là một địa điểm thuộc Đà Lạt. Loại hình: attraction. Các hoạt động nổi bật: khám...
#
# [Chunk 3] DL_0003 | 321 chars
# Quảng trường Lâm Viên là một địa điểm thuộc Đà Lạt. Loại hình: attraction. Các hoạt động nổi bật: kh...
# ============================================================
# 📦 Tạo DB mới... (DB rỗng, chuẩn bị tạo mới)
#   Batch 1: ✅ 100 chunks
#   Batch 2: ✅ 100 chunks
#   Batch 3: ✅ 100 chunks
#   Batch 4: ✅ 100 chunks
#   Batch 5: ✅ 100 chunks
#   Batch 6: ✅ 100 chunks
#   Batch 7: ✅ 100 chunks
#   Batch 8: ✅ 100 chunks
#   Batch 9: ✅ 100 chunks
#   Batch 10: ✅ 100 chunks
#   Batch 11: ✅ 100 chunks
#   Batch 12: ✅ 100 chunks
#   Batch 13: ✅ 100 chunks
#   Batch 14: ✅ 100 chunks
#   Batch 15: ✅ 100 chunks
#   Batch 16: ✅ 100 chunks
#   Batch 17: ✅ 100 chunks
#   Batch 18: ✅ 100 chunks
#   Batch 19: ✅ 100 chunks
#   Batch 20: ✅ 100 chunks
#   Batch 21: ✅ 100 chunks
#   Batch 22: ✅ 100 chunks
#   Batch 23: ✅ 100 chunks
#   Batch 24: ✅ 100 chunks
#   Batch 25: ✅ 100 chunks
#   Batch 26: ✅ 100 chunks
#   Batch 27: ✅ 100 chunks
#   Batch 28: ✅ 100 chunks
#   Batch 29: ✅ 100 chunks
#   Batch 30: ✅ 100 chunks
#   Batch 31: ✅ 100 chunks
#   Batch 32: ✅ 100 chunks
#   Batch 33: ✅ 100 chunks
#   Batch 34: ✅ 100 chunks
#   Batch 35: ✅ 100 chunks
#   Batch 36: ✅ 100 chunks
#   Batch 37: ✅ 100 chunks
#   Batch 38: ✅ 100 chunks
#   Batch 39: ✅ 100 chunks
#   Batch 40: ✅ 100 chunks
#   Batch 41: ✅ 100 chunks
#   Batch 42: ✅ 100 chunks
#   Batch 43: ✅ 100 chunks
#   Batch 44: ✅ 100 chunks
#   Batch 45: ✅ 100 chunks
#   Batch 46: ✅ 100 chunks
#   Batch 47: ✅ 100 chunks
#   Batch 48: ✅ 100 chunks
#   Batch 49: ✅ 100 chunks
#   Batch 50: ✅ 100 chunks
#   Batch 51: ✅ 100 chunks
#   Batch 52: ✅ 100 chunks
#   Batch 53: ✅ 100 chunks
#   Batch 54: ✅ 100 chunks
#   Batch 55: ✅ 100 chunks
#   Batch 56: ✅ 100 chunks
#   Batch 57: ✅ 100 chunks
#   Batch 58: ✅ 100 chunks
#   Batch 59: ✅ 100 chunks
#   Batch 60: ✅ 100 chunks
#   Batch 61: ✅ 100 chunks
#   Batch 62: ✅ 100 chunks
#   Batch 63: ✅ 100 chunks
#   Batch 64: ✅ 100 chunks
#   Batch 65: ✅ 100 chunks
#   Batch 66: ✅ 100 chunks
#   Batch 67: ✅ 100 chunks
#   Batch 68: ✅ 100 chunks
#   Batch 69: ✅ 100 chunks
#   Batch 70: ✅ 100 chunks
#   Batch 71: ✅ 100 chunks
#   Batch 72: ✅ 100 chunks
#   Batch 73: ✅ 100 chunks
#   Batch 74: ✅ 100 chunks
#   Batch 75: ✅ 100 chunks
#   Batch 76: ✅ 100 chunks
#   Batch 77: ✅ 100 chunks
#   Batch 78: ✅ 100 chunks
#   Batch 79: ✅ 100 chunks
#   Batch 80: ✅ 100 chunks
#   Batch 81: ✅ 100 chunks
#   Batch 82: ✅ 100 chunks
#   Batch 83: ✅ 100 chunks
#   Batch 84: ✅ 100 chunks
#   Batch 85: ✅ 100 chunks
#   Batch 86: ✅ 100 chunks
#   Batch 87: ✅ 100 chunks
#   Batch 88: ✅ 100 chunks
#   Batch 89: ✅ 100 chunks
#   Batch 90: ✅ 100 chunks
#   Batch 91: ✅ 100 chunks
#   Batch 92: ✅ 100 chunks
#   Batch 93: ✅ 100 chunks
#   Batch 94: ✅ 100 chunks
#   Batch 95: ✅ 100 chunks
#   Batch 96: ✅ 100 chunks
#   Batch 97: ✅ 100 chunks
#   Batch 98: ✅ 100 chunks
#   Batch 99: ✅ 100 chunks
#   Batch 100: ✅ 100 chunks
#   Batch 101: ✅ 100 chunks
#   Batch 102: ✅ 100 chunks
#   Batch 103: ✅ 100 chunks
#   Batch 104: ✅ 100 chunks
#   Batch 105: ✅ 100 chunks
#   Batch 106: ✅ 100 chunks
#   Batch 107: ✅ 100 chunks
#   Batch 108: ✅ 100 chunks
#   Batch 109: ✅ 100 chunks
#   Batch 110: ✅ 100 chunks
#   Batch 111: ✅ 100 chunks
#   Batch 112: ✅ 100 chunks
#   Batch 113: ✅ 8 chunks
#
# Hoàn tất: 11308 inserted, 0 failed | Tổng DB: 11308
#
#  Ingestion complete! Your documents are stored in Chroma DB and ready for RAG queries.
