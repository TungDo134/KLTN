# %%
# Cell 1: Load env
from dotenv import load_dotenv

load_dotenv()

# Cell 2: Setup path + import
from src.pipeline.rag_pipline import RAGStorage
import sys

sys.path.append("D:/KLTN/Project/BE_ChatBot")

RAGStorage().build_vector_db()
# Out:
# 📁 Cache dir: D:\KLTN\Project\BE_ChatBot\src\model\embeddings
# Loading embedding model on device using: 'cuda'...
# 🔧 Provider : huggingface
# 🔧 Model    : AITeamVN/Vietnamese_Embedding
# 🔧 Device   : cuda
# 🔧 Cache    : D:\KLTN\Project\BE_ChatBot\src\model\embeddings
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# Loading document from src/source_data/docs
# ============================================================
# Tổng documents: 11
# src\source_data\docs\22130315_22130109_NguyenDucCongSong.pdf
# src\source_data\docs\22130315_22130109_NguyenDucCongSong.pdf
# src\source_data\docs\22130315_22130109_NguyenDucCongSong.pdf
# src\source_data\docs\22130315_22130109_NguyenDucCongSong.pdf
# src\source_data\docs\22130315_22130109_NguyenDucCongSong.pdf
# src\source_data\docs\22130315_22130109_NguyenDucCongSong.pdf
# src\source_data\docs\Google.txt
# src\source_data\docs\Microsoft.txt
# src\source_data\docs\Nvidia.txt
# src\source_data\docs\SpaceX.txt
# src\source_data\docs\Tesla.txt
# ============================================================
# Splitting documents into chunks...
# Split into 1387 chunks
#
# [Chunk 1] src\source_data\docs\22130315_22130109_NguyenDucCongSong.pdf | 930 chars
# ĐỀ CƯƠNG CHI TIẾT KHÓA LUẬN TỐT NGHIỆP
# 1. Tên đề tài:
# - Xây dựng chatbot gợi ý địa điểm và tạo lịc...
#
# [Chunk 2] src\source_data\docs\22130315_22130109_NguyenDucCongSong.pdf | 995 chars
# mà chưa kết hợp được yếu tố thời gian, sở thích cá nhân để tạo nên một lịch trình
# hợp lý.
# 5. Mục t...
#
# [Chunk 3] src\source_data\docs\22130315_22130109_NguyenDucCongSong.pdf | 164 chars
# TRƯỜNG ĐẠI HỌC NÔNG LÂM TP.HCM CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM
# KHOA CÔNG NGHỆ THÔNG TIN Độc lập ...
# ============================================================
# 📦 Tạo DB mới... (DB rỗng, chuẩn bị tạo mới)
#   Batch 1: ✅ 100 chunks
#   Batch 2: ✅ 100 chunks
#   Batch 3: ✅ 100 chunks
#   Batch 4: ✅ 100 chunks
#   Batch 5: ✅ 100 chunks
#   Batch 6: ✅ 100 chunks
#   Batch 7: ✅ 100 chunks
#   Batch 8: ✅ 100 chunks
#   Batch 9: ✅ 100 chunks
#   Batch 10: ✅ 100 chunks
#   Batch 11: ✅ 100 chunks
#   Batch 12: ✅ 100 chunks
#   Batch 13: ✅ 87 chunks
#
# Hoàn tất: 1387 inserted, 0 failed | Tổng DB: 1387
#
#  Ingestion complete! Your documents are stored in Chroma DB and ready for RAG queries.
